# %% [markdown]
# ## This Specific Notebook
# * Notebook with visuals from Visualize
# * https://www.ncdc.noaa.gov/cdo-web/
# * http://climod2.nrcc.cornell.edu/
#     * Daily data listing
#     * Search Bradley International Airport
# * Note:
#     * T: Trace amount- Less than 0.01" precipitation; less than 0.1" snowfall; less than 1" snow depth.
#     * S: Subsequent- Indicates the observation is missing, but is included in a subsequent value.
#     * A: Accumulated- Indicates an accumulated value which includes the current day and any immediately preceeding missing days (starting with a day flagged by "S").
#     * M: Missing.
# * Note:
#     * I just copied and pasted the data from 12.27.2020 to 1.3.2021 in to the existing excel file with all the dates so I had to drop then add back in Year, Month, Day columns.
#     * Going forward I should just copy and paste the new dates into a csv file then merge them into a clean csv for analysis

# %% [markdown]
# ___

# %% [markdown]
# # Importing Libraries and data

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
sns.set()

#from fbprophet import Prophet

# %%
df = pd.read_csv('Bradley_1_1_1980_12_31_2021_Clean.csv')

# %%
# df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# Date                        object
# MaxTemperature               int64
# MaxTemperatureNormal       float64
# MaxTemperatureDeparture    float64
# MinTemperature               int64
# MinTemperatureNormal       float64
# MinTemperatureDeparture    float64
# AvgTemperature             float64
# AvgTemperatureNormal       float64
# AvgTemperatureDeparture    float64
# PrecipitationNormal        float64
# PrecipitationDeparture     float64
# Snowfall                   float64
# SnowfallNormal             float64
# SnowfallDeparture           object
# SnowDepth                   object
# HDD                          int64
# HDDNormal                  float64
# HDDDeparture               float64
# CDD                          int64
# CDDNormal                  float64
# CDDDeparture               float64
# GDD                          int64
# Precipitation              float64
# Year                         int64
# Month                        int64
# ...

# %% [markdown]
# ### Convert Date to datetime

# %%
df[['Date']] = df[['Date']].apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# Unnamed: 0                          int64
# Date                       datetime64[ns]
# MaxTemperature                      int64
# MaxTemperatureNormal              float64
# MaxTemperatureDeparture           float64
# MinTemperature                      int64
# MinTemperatureNormal              float64
# MinTemperatureDeparture           float64
# AvgTemperature                    float64
# AvgTemperatureNormal              float64
# AvgTemperatureDeparture           float64
# PrecipitationNormal               float64
# PrecipitationDeparture            float64
# Snowfall                          float64
# SnowfallNormal                    float64
# SnowfallDeparture                  object
# SnowDepth                          object
# HDD                                 int64
# HDDNormal                         float64
# HDDDeparture                      float64
# CDD                                 int64
# CDDNormal                         float64
# ...

# %% [markdown]
# ___

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Looking at things like seeing temperature for a specific date from 1980 to 2.28.2021

# %%
from clean_data import Data

# %%
Data(df)

# %%
from evaluate import *

# %%
eval = Evaluate(df)

# %%
#eval.histograms()

# %%
#eval.kde_plots()

# %%
#eval.dist_plots()

# %%
from visualize import *

# %%
### Input month and date and precipitation, snowfall, averag temp, min temp or max temp and get bar chart with line showing increase or decrease (whatever that's called)
viz = Visualize(df)

# %% [markdown]
# # Daily AvgTemperature, Precipitation and Snowfall

# %% [markdown]
# ### AvgTemperature

# %%
viz.dailygraph(month = 12, day = 30, feature = 'AvgTemperature')

# %% [markdown]
# ### Precipitation

# %%
viz.dailygraph(month = 5, day = 31, feature = 'Precipitation')

# %% [markdown]
# ### Snowfall

# %%
viz.dailygraph(month = 12, day = 24, feature = 'Snowfall')

# %% [markdown]
# ### Descriptive Statistics

# %%
viz.stats()
# Out:
#         Snowfall
# count  42.000000
# mean    0.102381
# std     0.384764
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.000000
# max     2.100000

# %% [markdown]
# # aggregations is Yearly and Monthly Charts

# %% [markdown]
# ### Yearly Precipitation

# %%
viz.aggregations(year = True, month = False, feature = 'Precipitation', function = 'sum')

# %% [markdown]
# ### Yearly Temperature

# %%
viz.aggregations(year = True, month = False, feature = 'AvgTemperature', function = 'mean')

# %% [markdown]
# ### Yearly Total Snowfall

# %%
viz.aggregations(year = True, month = False, feature = 'Snowfall', function = 'sum')

# %% [markdown]
# ### Average Temperature per Month

# %%
viz.aggregations(year = False, month = True, feature = 'AvgTemperature', function = 'mean')

# %% [markdown]
# ### Total Precipitation per Month

# %%
viz.aggregations(year = False, month = True, feature = 'Precipitation', function = 'sum')

# %% [markdown]
# ### Total Snowfall per Month

# %%
viz.aggregations(year = False, month = True, feature = 'Snowfall', function = 'sum')

# %%
viz.aggregations(year = True, month = False, feature = 'Snowfall', function = 'sum')

# %%
viz.aggregations(year = False, month = True, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 12, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 12, feature = 'MinTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 12, feature = 'MaxTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 12, feature = 'Precipitation', function = 'sum')

# %%
viz.yearmonth(year = False, month = 4, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 4, feature = 'Precipitation', function = 'sum')

# %%
viz.yearmonth(year = 2020, month = False, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = 2010, month = False, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = 2000, month = False, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = 1990, month = False, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = 1980, month = False, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 1, feature = 'AvgTemperature', function = 'mean')

# %%
viz.yearmonth(year = False, month = 2, feature = 'AvgTemperature', function = 'mean')
